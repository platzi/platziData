# %% [markdown]
# # Ingeniería de Datos con Python

# %% [markdown]
# ## Introducción

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print('segunda linea')
# Out:
# segunda linea

# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# ### Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.14159
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'David'

# %% [markdown]
# ### Estructurados

# %%
from IPython.display import Image

Image('mysql_table_example.png')

# %% [markdown]
# ### Semi estructurados

# %%
Image('html_markup_example.png')

# %% [markdown]
# ### No estructurados

# %% [markdown]
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than *right* now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Solicitudes a la web

# %%
import requests

response = requests.get('https://www.platzi.com')

print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html lang="es_ES" data-cast-api-enabled="true"><head><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no" /><title>Platzi: Cursos online profesionales de tecnología</title><link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" /><link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png"><link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" /><meta name="description" content="Aprende desde cero a crear el futuro de la web. Cursos de Desarrollo, Diseño, Marketing, y Negocios."><meta name="theme-color" content="#15210B"/><!-- og tags Facebook --><meta property="fb:app_id" content="263680607075199" /><meta property="fb:admins" content="1030603473" /><meta property="og:description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><meta property="og:title" content="Platzi: Cursos online profesionales de tecnología" /><meta property="og:type" content="website" /><meta property="og:url" content="https://platzi.com/"/><meta property="og:image" content="https://static.platzi.com/static/website/v2/images/social/social.a0407ac580e4.jpg" /><meta property="og:site_name" content="platzi.com" /><!-- og tags Google+ --><meta itemprop="description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><!-- Twitter Cards --><meta property="twitter:account_id" content="4503599630205252" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:site" content="@Platzi" /><meta name="twitter:title" content="Platzi: Cursos online profesionales de tecnología" /><meta name="twitter:description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><meta name="twitter:creator" content="@Platzi" /><meta name="twitter:image:src" content="https://static.platzi.com/static/website/v2/images/social/social.a0407ac580e4.jpg" /><meta name="twitter:domain" content="platzi.com" /><!-- SEO --><link rel="canonical" href="https://platzi.com/" /><!-- hreflang --><link rel="alternate" href="https://courses.platzi.com/" hreflang="en" /><link rel="alternate" href="https://platzi.com/" hreflang="es" /><!-- hreflang --><link rel="manifest" href="/onesignal.json" /><style type="text/css" defer async>
#   .onesignal-popover-dialog {
#     pointer-events: none !important;
#   }
#   .onesignal-popover-dialog > #normal-popover {
#     pointer-events: auto !important;
#   }
# </style><script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async></script><script type="text/javascript" defer async>
#   var OneSignal = window.OneSignal || [];
#    OneSignal.push(function() {
#      OneSignal.init({
#        appId: "8adc9051-61fc-438e-b19a-739a6bf780e5",
#      });
#    });
#  </script><!-- Analytics and FB Pixel Code --><script defer async>
#             (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#             window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#
#
#
#                 // Create Trackers
#                 ga('create', 'UA-76863-18', 'auto', 'platziPublicES');
#                 ga('create', 'UA-76863-27', 'auto', 'platziFull');
#
#
#                 // Require Plugins for platziPublicES
#                 ga('platziPublicES.require', 'ecommerce');
#                 ga('platziPublicES.require', 'outboundLinkTracker');
#                 ga('platziPublicES.require', 'socialWidgetTracker');
#
#                 // Require Plugins for platziFull
#                 ga('platziFull.require', 'ecommerce');
#                 ga('platziFull.require', 'outboundLinkTracker');
#                 ga('platziFull.require', 'socialWidgetTracker');
#
#
#                 // If userId, update userId
#
#
#                 //Send Pageview
#                 ga('platziPublicES.send', 'pageview');
#                 ga('platziFull.send', 'pageview');
#
#                 ga('platziPublicES.set', 'dimension2', 'anonymous');
#                 ga('platziFull.set', 'dimension2', 'anonymous');
#
#
#
#         </script><!-- Autotrack plugin for Google Analytics --><script async src="https://cdnjs.cloudflare.com/ajax/libs/autotrack/2.4.1/autotrack.js" defer async></script><!-- Facebook Pixel Code --><script defer async>
#                 !function(f,b,e,v,n,t,s)
#                 {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                     n.queue=[];t=b.createElement(e);t.async=!0;
#                     t.src=v;s=b.getElementsByTagName(e)[0];
#                     s.parentNode.insertBefore(t,s)}(window, document,'script',
#                     'https://connect.facebook.net/en_US/fbevents.js');
#                 fbq('init', '1545967215651797');
#                 fbq('track', 'PageView');
#             </script><noscript><img height="1" width="1" style="display:none"
#                            src="https://www.facebook.com/tr?id=1545967215651797&ev=PageView&noscript=1"
#             /></noscript><!-- End Facebook Pixel Code --><script type="text/javascript">
#             _linkedin_data_partner_id = "274754";
#             </script><script type="text/javascript" defer async>
#             (function(){var s = document.getElementsByTagName("script")[0];
#             var b = document.createElement("script");
#             b.type = "text/javascript";b.async = true;
#             b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#             s.parentNode.insertBefore(b, s);})();
#             </script><noscript><img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=274754&fmt=gif" /></noscript><!-- End Analytics and FB Pixel Code --><!-- Twitter universal website tag code --><script defer async>
#             !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
#             },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
#                 a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
#             // Insert Twitter Pixel ID and Standard Event data below
#             twq('init','nyfpx');
#             twq('track','PageView');
#         </script><!-- End Twitter universal website tag code --><!-- Hotjar Tracking Code for www.platzi.com --><script defer async>
#           (function(h,o,t,j,a,r){
#               h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#               h._hjSettings={hjid:430680,hjsv:5};
#               a=o.getElementsByTagName('head')[0];
#               r=o.createElement('script');r.async=1;
#               r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#               a.appendChild(r);
#           })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#         </script><!-- Begin Inspectlet JS Code --><script type="text/javascript" id="inspectletjs" defer async>
#             (function() {
#             var insp_ab_loader = false; // set this boolean to false to disable the A/B testing loader
#             window.__insp = window.__insp || [];
#             __insp.push(['wid', 1550190489]);
#             var ldinsp = function(){
#             if(typeof window.__inspld != "undefined") return; window.__inspld = 1; var insp = document.createElement('script'); insp.type = 'text/javascript'; insp.async = true; insp.id = "inspsync"; insp.src = ('https:' == document.location.protocol ? 'https' : 'http') + '://cdn.inspectlet.com/inspectlet.js?wid=1550190489&r=' + Math.floor(new Date().getTime()/3600000); var x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(insp, x);if(typeof insp_ab_loader != "undefined" && insp_ab_loader){ var adlt = function(){ var e = document.getElementById('insp_abl'); if(e){ e.parentNode.removeChild(e); __insp.push(['ab_timeout']); }}; var adlc = "body{ visibility: hidden !important; }"; var adln = typeof insp_ab_loader_t != "undefined" ? insp_ab_loader_t : 1200; insp.onerror = adlt; var abti = setTimeout(adlt, adln); window.__insp_abt = abti; var abl = document.createElement('style'); abl.id = "insp_abl"; abl.type = "text/css"; if(abl.styleSheet) abl.styleSheet.cssText = adlc; else abl.appendChild(document.createTextNode(adlc)); document.head.appendChild(abl); } };
#             setTimeout(ldinsp, 0);
#             })();
#         </script><!-- End Inspectlet JS Code --><!-- add more stylesheets --><link type="text/css" href="https://static.platzi.com/static/css/core/header-v2.2ce3ec38ec20b6bc7672.css.gz" rel="stylesheet"/><link type="text/css" href="https://static.platzi.com/static/css/d/contact-modal.b4340e3d744a50de60df.css.gz" rel="stylesheet"/><link type="text/css" href="https://static.platzi.com/static/css/d/contact-modal.b4340e3d744a50de60df.css.gz" rel="stylesheet"/><link type="text/css" href="https://static.platzi.com/static/css/core/home-v3.2ce3ec38ec20b6bc7672.css.gz" rel="stylesheet"/><!-- add more metatags --><script type="text/javascript">
#             window.header = {"awards": [{"logo": "https://static.platzi.com/static/images/footer/yc.png", "name": "Y Combinator", "url": "https://platzi.com/blog/platzi-y-combinator/"}, {"logo": "https://static.platzi.com/static/images/footer/asugsv.png", "name": "ASU + GSV Summit", "url": "https://platzi.com/blog/platzi-gana-premio-educacion/"}], "lastCourse": [{"exam_url": "", "id": "", "slug": "", "url": "", "completed": 0, "career": "", "approved": "", "badge": "", "title": ""}], "plan": "", "userId": "", "locale": "es", "socials": [{"icon": "icon-twt", "url": "https://twitter.com/platzi"}, {"icon": "icon-youtube-play", "url": "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ"}, {"icon": "icon-fcbk", "url": "https://facebook.com/platzi"}, {"icon": "icon-instagram", "url": "https://www.instagram.com/platzi/"}], "referalUrl": false, "enableSearch": true, "enableSubscription": true, "options": [{"title": "Preguntas frecuentes", "url": "/faq/"}, {"title": "Cont\u00e1ctanos", "url": "/contacto/"}, {"title": "Prensa", "url": "/prensa/"}, {"title": "Conferencias", "url": "/conf/todas/"}, {"title": "T\u00e9rminos y Condiciones", "url": "/tos/"}, {"title": "Privacidad", "url": "/privacidad/"}, {"title": "Estudiantes", "url": "/historias/"}, {"title": "Hola", "url": "/hola/"}], "menuItems": [{"name": "Cursos", "url": "/cursos/"}, {"name": "Cont\u00e1ctanos", "type": "contact", "url": ""}, {"name": "Blog", "url": "/blog/"}, {"name": "Agenda", "url": "/agenda/"}, {"name": "Foro", "url": "/foro/"}], "avatar": "", "name": "", "profileUrl": "", "points": "", "live": {"active": false, "time": "", "url": ""}, "loggedMenu": [{"icon": "icon-suitecase_B", "name": "Empleos", "url": "/empleos/"}, {"icon": "icon-bell", "name": "Notificaciones", "type": "notifications", "url": "/clases/notificaciones/"}, {"icon": "icon-cloud", "name": "Mensajes Directos", "type": "direct_messages", "url": "/direct-messages/"}, {"icon": "icon-gift_A", "name": "Obt\u00e9n 1 mes gratis", "type": "referal", "url": "/mi-suscripcion/referidos/"}, {"icon": "icon-platzi", "name": "Mi Suscripci\u00f3n", "type": "my_subscription", "url": "/mi-suscripcion/"}], "isLogged": false, "messages": {"login_courses_text": "Accede a m\u00e1s de 120 cursos", "login": "Iniciar sesi\u00f3n", "courses": "Cursos", "username": "\u00a1Hola! {user_name}", "more_results": "M\u00e1s resultados", "view_plans": "Quiero saber m\u00e1s", "live_in": "Live en ", "switch_language": "Do you want to switch to Platzi in English?", "init_plan": "Iniciar mi plan", "switch_english": "Yes, switch to English", "continue_watching": "Continua viendo", "menu": "Men\u00fa", "careers": "Carreras", "init_plan2": "Planes", "no_results": "No tenemos resultados destacados", "subscriptionTime": "Tienes {subscription_time} d\u00edas de tu Plan", "all_courses": "Ver todos mis cursos", "live": "live", "avanced_search": "Presiona ENTER para una busqueda avanzada", "login_opportunities": "Accede a mejores oportunidades laborales", "logout": "Cerrar sesi\u00f3n", "login_live_text": "Participa en sesiones en vivo y foros de Platzi", "user_login": "Inicia sesi\u00f3n o crea tu cuenta", "view_profile": "Ver mi Perfil"}, "username": "", "subscriptionTime": "", "isHispanic": true};
#             var lang = "es";
#         </script><!-- script to load browser based polyfills --><script src="https://cdn.polyfill.io/v2/polyfill.min.js"></script><script defer async>
#             // display a warning in the console
#             console.log('%cStop!', 'color: red;font-size:2.5rem;font-weight:bold;');
#             console.log('%cThis is a browser feature intended for developers. If someone told you to copy-paste something here to enable a Platzi feature or "hack" someone\'s account, it is a scam and will give them access to your Platzi account.', 'font-size:1.25rem;line-height:1.1;margin-top:.5em');
#         </script></head><body><div id="contact-us-modal"></div><div id="header-v2"><div data-reactroot="" data-reactid="1" data-react-checksum="-1204037814"><div id="overlay" class="Header-v2-overlay" data-reactid="2"></div><div class="Header-v2 Header-v2-content" data-reactid="3"><div class="Logo" data-reactid="4"><a href="/" title="Platzi.com" data-reactid="5"><img src="data:image/png;base64,..." srcset="data:image/png;base64,... 1x, data:image/png;base64,... 2x" class="Logo-full" alt="Platzi.com" data-reactid="6"/></a></div><div class="Nav-header" data-reactid="7"><div class="Plive" data-reactid="8"></div><div class="Actionsv2" data-reactid="9"><div data-reactid="10"><div class="Actionsv2-menu" data-reactid="11"><div class="isDesktop" data-reactid="12"><span data-reactid="13">Iniciar mi plan</span></div><div class="isMobile" data-reactid="14"><span data-reactid="15">Planes</span></div><i class="icon-arrow-down toggle-down" data-reactid="16"></i></div><div class="Actionsv2-content" data-reactid="17"><div class="triangled" data-reactid="18"></div><div class="box" data-reactid="19"><div class="Plans" data-reactid="20"><div class="Plans-content" data-reactid="21"><figure data-reactid="22"><img src="https://static.platzi.com/static/images/header-v2/individual.png" alt="Plan individual" data-reactid="23"/></figure><h2 data-reactid="24">Plan Individual</h2><p data-reactid="25"><span data-reactid="26">Desarrolla las habilidades de tu equipo en diferentes áreas como programación, marketing, diseño y negocios</span></p><div class="ContinueButton" data-reactid="27"><a href="/precios/" class="btn btn-Green btn---small" data-reactid="28"><span data-reactid="29">Quiero saber más</span></a></div></div></div><div class="Plans" data-reactid="30"><div class="Plans-content" data-reactid="31"><figure data-reactid="32"><img src="https://static.platzi.com/static/images/header-v2/empresas.png" alt="Plan empresas" data-reactid="33"/></figure><h2 data-reactid="34">Plan para Empresas</h2><p data-reactid="35"><span data-reactid="36">Desarrolla las habilidades de tu equipo en diferentes áreas como programación, marketing, diseño y negocios</span></p><div class="ContinueButton" data-reactid="37"><a href="/empresas/" class="btn btn-Green btn---small" data-reactid="38"><span data-reactid="39">Quiero saber más</span></a></div></div></div></div></div></div></div><div class="Menu" data-reactid="40"><div class="Menu-dropdown" data-reactid="41"><div class="Menu-title" data-reactid="42"><span data-reactid="43">Menú</span></div></div><div class="Menu-content" data-reactid="44"><div class="Searchv" data-reactid="45"><div class="Searchv-content" data-reactid="46"><form action="/search/" class="" data-reactid="47"><input type="text" placeholder="Buscar en Platzi" name="search" autocomplete="off" data-reactid="48"/><button class="Searchv-icon" data-reactid="49"><span class="icon-search" data-reactid="50"></span></button></form></div><div class="Searchv-results" data-reactid="51"></div></div><div data-reactid="52"><ul class="Menu-list" data-reactid="53"><li class="Menu-list-item" data-reactid="54"><a href="/cursos/" data-reactid="55"><div data-reactid="56">Cursos</div></a></li><li class="Menu-list-item" data-reactid="57"><a href="#" id="menu-modal" data-reactid="58"><div data-reactid="59">Contáctanos</div></a></li><li class="Menu-list-item" data-reactid="60"><a href="/blog/" data-reactid="61"><div data-reactid="62">Blog</div></a></li><li class="Menu-list-item" data-reactid="63"><a href="/agenda/" data-reactid="64"><div data-reactid="65">Agenda</div></a></li><li class="Menu-list-item" data-reactid="66"><a href="/foro/" data-reactid="67"><div data-reactid="68">Foro</div></a></li></ul><div class="UserLogin" data-reactid="69"><div class="UserLogin-content" data-reactid="70"><div class="UserLogin-button" data-reactid="71"><a href="/login" class="btn btn-green btn--big" data-reactid="72"><span data-reactid="73">Inicia sesión o crea tu cuenta</span></a></div><div class="Us ...
#
# <!-- /react-text --><!-- react-text: 761 -->&quot;<!-- /react-text --></p><div class="Testimony-info" data-reactid="762"><div class="Testimony-name not-social-network" data-reactid="763"><!-- react-text: 764 -->Ricardo Barrera <!-- /react-text --><img class="Testimony-flag" src="https://static.platzi.com/media/flags/US.png" alt="Estados unidos" data-reactid="765"/></div><!-- react-text: 766 --><!-- /react-text --></div></div><a href="/@rbarrera87/" class="Testimony-link" data-reactid="767"></a></div><div class="Testimony" data-reactid="768"><figure data-reactid="769"><img src="https://static.platzi.com/media/testimony/julian-duque.jpg" alt="Julian Duque" data-reactid="770"/></figure><div class="Testimony-content" data-reactid="771"><p data-reactid="772"><!-- react-text: 773 -->&quot;<!-- /react-text --><!-- react-text: 774 -->Siempre hay oportunidades para compartir con estudiantes en vivo y me siento generando un impacto.<!-- /react-text --><!-- react-text: 775 -->&quot;<!-- /react-text --></p><div class="Testimony-info" data-reactid="776"><div class="Testimony-name" data-reactid="777"><!-- react-text: 778 -->Julian Duque<!-- /react-text --><img class="Testimony-flag" src="https://static.platzi.com/media/flags/US.png" alt="Estados unidos" data-reactid="779"/></div><a href="https://twitter.com/julian_duque" class="Testimony-social" data-reactid="780"><!-- react-text: 781 -->@<!-- /react-text --><!-- react-text: 782 -->julian_duque<!-- /react-text --></a></div></div><a href="/@julian_duque/" class="Testimony-link" data-reactid="783"></a></div></div></div></div><div class="CTA" data-reactid="784"><div class="u-wrapper" data-reactid="785"><div class="CTA-container" data-reactid="786"><figure data-reactid="787"><img src="css/study-with-us-4.01ece3d87f7686ab8618a4e946ce4d53.png" width="85" alt="¿Qué te detiene a invertir en ti?" data-reactid="788"/></figure><p data-reactid="789"><span data-reactid="790">Clases en video, lecturas, proyectos colaborativos, desafíos, quizzes, ejercicios, en tu móvil o escritorio</span></p><p class="is-highlighted" data-reactid="791"><span data-reactid="792">¿Qué te detiene a invertir en ti?</span></p><div class="CTA-link" data-reactid="793"><a href="/login/" class="btn btn-green btn--big btn--responsive" data-reactid="794"><span data-reactid="795">Comienza a estudiar</span></a></div></div></div></div><div class="Pricing" data-reactid="796"><h2 data-reactid="797">Elige un plan y empieza a estudiar</h2><div class="Plans u-wrapper is-xs" data-reactid="798"><div class="StickyPlan" data-reactid="799"><div class="PlanTabs" data-reactid="800"><div class="PlanTab" data-reactid="801"><div class="PlanTab-container is-active" data-reactid="802"><div class="PlanTab-title" data-reactid="803"><span data-reactid="804">Platzi Expert</span></div></div></div><div class="PlanTab" data-reactid="805"><div class="PlanTab-container" data-reactid="806"><div class="PlanTab-title" data-reactid="807"><span data-reactid="808">Platzi Basic</span></div></div></div><div class="PlanTab" data-reactid="809"><div class="PlanTab-container" data-reactid="810"><div class="PlanTab-title" data-reactid="811"><span data-reactid="812">Un solo curso</span></div></div></div></div><div class="CurrentPlanCTA" data-reactid="813"><div class="CurrentPlanCTA-info" data-reactid="814"><div class="CurrentPlanCTA-price" data-reactid="815"><figure data-reactid="816"><img src="https://static.platzi.com/media/flags/CO.png" width="14" height="14" alt="pesos" data-reactid="817"/></figure><p data-reactid="818"><!-- react-text: 819 -->$<!-- /react-text --><!-- react-text: 820 -->74.100<!-- /react-text --><!-- react-text: 821 --> / mes<!-- /react-text --></p></div><div class="CurrentPlanCTA-subtitle" data-reactid="822"><!-- react-text: 823 -->En un solo pago de<!-- /react-text --><span data-reactid="824"> $890.000</span></div></div><div class="CurrentPlanCTA-cta" data-reactid="825"><a href="/comprar/anual/?course=todos" class="btn-green btn--medium" data-reactid= ...
#
#
#
#
# Apple adquiere a Market por 4.75 mil millones
#
#
# Apple adquiere a Shazam
#
#
# Renuncian lo</div></div><div class="PostCard-author" data-reactid="1164"><figure data-reactid="1165"><img alt="cvander" src="https://static.platzi.com/media/avatars/cvander_a613bc8a-9b53-4dd0-8c67-3e273377ccdf.jpg" height="20" data-reactid="1166"/></figure><span data-reactid="1167">cvander</span></div></div></article><article class="PostCard-container" data-reactid="1168"><div class="PostCard" data-reactid="1169"><a href="/blog/comunicacion-efectiva-empresas/" data-reactid="1170"></a><div style="background-image:url(https://static.platzi.com/media/blog/comunicacion_efectiva-0a70d7be-2a50-4495-bad9-9b2db74f82dd.png);background-color:#98CA3F;" class="PostCard-header" data-reactid="1171"><div class="Star is-level-1 is-medium" data-reactid="1172"><span class="Star-icon icon-thumbs-up" data-reactid="1173"></span><span class="Star-number" data-reactid="1174">10</span></div></div><div class="PostCard-body" data-reactid="1175"><h3 data-reactid="1176">¿Cómo lograr comunicación efectiva en tu empresa?</h3><div class="PostCard-content" data-reactid="1177">Una pieza fundamental y clave del proceso de transformación digital es lograr una comunicación efectiva en la empresa.
# Hay varias formas de lograrlo, pero lo im</div></div><div class="PostCard-author" data-reactid="1178"><figure data-reactid="1179"><img alt="GisseJo" src="https://static.platzi.com/media/avatars/GisseJo_c4ac3a7d-2e48-4019-9e03-90c978686a1e.jpg" height="20" data-reactid="1180"/></figure><span data-reactid="1181">GisseJo</span></div></div></article><article class="PostCard-container" data-reactid="1182"><div class="PostCard" data-reactid="1183"><a href="/blog/5-mitos-diseno/" data-reactid="1184"></a><div style="background-image:url(https://static.platzi.com/media/blog/5-mitos-diseno-3fe29a60-1530-4c0e-95e9-db069d299135.jpg);background-color:#98CA3F;" class="PostCard-header" data-reactid="1185"><div class="Star is-level-1 is-medium" data-reactid="1186"><span class="Star-icon icon-thumbs-up" data-reactid="1187"></span><span class="Star-number" data-reactid="1188">20</span></div></div><div class="PostCard-body" data-reactid="1189"><h3 data-reactid="1190">5 mitos sobre el trabajo de un diseñador</h3><div class="PostCard-content" data-reactid="1191">Entrar al mundo del diseño puede parecer algo imposible de hacer si no tienes talento innato. Pero este don especial no existe y la realidad es que, como cualqu</div></div><div class="PostCard-author" data-reactid="1192"><figure data-reactid="1193"><img alt="Danigo21" src="https://static.platzi.com/media/avatars/Danigo21_dc571fdf-af14-4ea2-971e-ad063ee92c41.jpg" height="20" data-reactid="1194"/></figure><span data-reactid="1195">Danigo21</span></div></div></article></div></div></div></div><div class="Register" data-reactid="1196"><div class="row u-row-wrapper" data-reactid="1197"><div class="col-xs-12 col-sm-6 col-md-4" data-reactid="1198"><p data-reactid="1199"><span data-reactid="1200">Aprende de expertos en programación, diseño, marketing, startups, video y web.</span></p><p class="is-highlighted" data-reactid="1201"><span data-reactid="1202">Suscríbete hoy</span></p><form method="post" class="PreRegisterForm isHomev3" data-reactid="1203"><p class="big PreRegisterForm-title" data-reactid="1204"><strong data-reactid="1205">Regístrate a Platzi</strong></p><div class="row" data-reactid="1206"><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1207"><div class="form-group" data-reactid="1208"><div class="icon icon-name-circle" data-reactid="1209"></div><input type="text" class="form-control" name="first_name" placeholder="Nombre" data-reactid="1210"/></div></div><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1211"><div class="form-group" data-reactid="1212"><div class="icon icon-mail-circle" data-reactid="1213"></div><input type="email" class="form-control" name="email" placeholder="Correo electrónico" data-reactid="1214"/></div></div><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1215"><div class="checkbox" data-reactid="1216"><input type="checkbox" id="tos" class="form-control" name="tos" value="false" data-reactid="1217"/><label class="checkbox-label" for="tos" data-reactid="1218"></label><label data-reactid="1219"><span data-reactid="1220"><!-- react-text: 1221 -->Acepto los <!-- /react-text --><a href="/terminos/" target="_blank" data-reactid="1222"><span data-reactid="1223">Términos de servicio</span></a><!-- react-text: 1224 --> y <!-- /react-text --><a href="/privacidad/" target="_blank" data-reactid="1225"><span data-reactid="1226">Políticas de privacidad</span></a><!-- react-text: 1227 --> de Platzi<!-- /react-text --></span></label></div></div><input type="hidden" value="1" name="landings" data-reactid="1228"/></div><input type="submit" class="btn-green btn--full-width btn--medium" value="Comienza ahora" data-reactid="1229"/></form><p data-reactid="1230"><!-- react-text: 1231 -->O llámanos, en Bogotá al <!-- /react-text --><br data-reactid="1232"/><!-- react-text: 1233 -->+57 316 6126223<!-- /react-text --></p></div></div></div></div></section><footer id="footer-v2"><div class="AppFooter" data-reactroot="" data-reactid="1" data-react-checksum="780398535" ...
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=263680607075199&version=v2.0";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));</script><!-- End SDK de Facebook --><!-- SDK Google Plus --><script type="text/javascript">
#       (function() {
#         var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
#         po.src = 'https://apis.google.com/js/plusone.js?onload=OnLoadCallback';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
#       })();
#     </script><!-- End SDK Google Plus --><!-- SDK Twitter --><script>window.twttr = (function (d, s, id) {
#       var t, js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src= "https://platform.twitter.com/widgets.js";
#       fjs.parentNode.insertBefore(js, fjs);
#       return window.twttr || (t = { _e: [], ready: function (f) { t._e.push(f); } });
#     }(document, "script", "twitter-wjs"));</script><!-- End SDK Twitter --><!-- Google Tag Manager --><noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-KSZ9RW"
#     height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-KSZ9RW');</script><!-- End Google Tag Manager --><!-- Twitter Pixel Compra--><script src="//platform.twitter.com/oct.js" type="text/javascript" async></script><!-- End Twitter Pixel Compra--><script type="text/javascript" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js" async></script><script>
#             var visits = parseInt(window.localStorage.getItem('visits-counter'), 10) || 0;
#             if (visits < 35) {
#                 window.localStorage.setItem('visits-counter', visits + 1)
#             }
#             if (visits === 10 || visits === 20 || visits === 30) {
#                 window.openContact = true;
#             }
#
#         </script><script>
#                 window.contactInfo = {
#                     hasSubscription: false,
#                     isAuthenticated: false,
#                     country: "colombia",
#                     flag: "https://static.platzi.com/static/images/languajes/Colombia.jpg",
#                     isOrganizer: false,
#                     lang: "es",
#                     i18n: {'contactus.subtitle': 'Elige el medio que más te convenga, te sugerimos ', 'telephone': 'Teléfono', 'contactus.title': '¿Tienes dudas o quieres comunicarte con nosotros?', 'dm': 'Mensaje Directo', 'write': 'Escríbenos'},
#                     enabled: false,
#                     accepted_gdpr: false,
#                     userId: '0',
#                 }
#                 window.isHispanic = true
#             </script><script>
#     window.client_data = {"can_buy": true, "userType": "unlogged", "courses": [{"id": 1241, "title": "Bienvenido a Platzi", "slug": "bienvenido", "free": false, "order": 0, "description": "Conoce la plataforma y s\u00e1cale el m\u00e1ximo provecho a los cursos. ", "image": "https://static.platzi.com/media/achievements/platzi-bd.png", "color": "fff", "badge": "https://static.platzi.com/media/achievements/platzi-bd.png", "cover_url": "", "cover_vertical_url": "", "social_image_url": "", "social_description": "", "lang": "es", "video": "", "url": "/clases/bienvenido/", "live_url": "/clases/bienvenido//live", "is_required": false}, {"id": 1227, "title": "C\u00f3mo conseguir trabajo en Programaci\u00f3n", "slug": "developer", "free": false, "order": 0, "description": "Potencia tus habilidades y aprovecha tu perfil profesional para conseguir el trabajo de tus sue\u00f1os en el \u00e1rea de desarrollo. Aprende y crece con \u00e9xito para emplearte en grandes empresas, multinacionales, trabajo freelance, y por qu\u00e9 no, Silicon Valley.", "image": "https://static.platzi.com/media/achievements/platzi-bd.png", "color": "#372859", "badge": "https://static.platzi.com/media/achievements/badge-developer-e3ea96ae-cf89-4966-90ce-2ca74f3ed331.png", "cover_url": "", "cover_vertical_url": "", "social_image_url": "https://static.platzi.com/media/courses/og-developer.png", "social_description": "Potencia tus habilidades y aprovecha tu perfil profesional para conseguir el trabajo de tus sue\u00f1os en el \u00e1rea de programaci\u00f3n.", "lang": "es", "video": "", "url": "/clases/developer/", "live_url": "/clases/developer//live", "is_required": false}, {"id": 1257, "title": "C\u00f3mo prepararte profesionalmente para el futuro", "slug": "futuro-profesional", "free": false, "order": 0, "description": "Tener una proyecci\u00f3n profesional acertada es todo un reto en este momento de cambio exponencial, en el que los avances tecnol\u00f3gicos crecen m\u00e1s r\u00e1pido que la capacidad de adaptaci\u00f3n humana. Construye un perfil que te ayude a destacar en el mundo laboral, fortalece tus habilidades y prep\u00e1rate para enfrentar el futuro.", "image": "https://static.platzi.com/media/achievements/platzi-bd.png", "color": "#D95A34", "badge": "https://static.platzi.com/media/achievements/badges-futuro-8f5f57f5-bcdf-4fa5-9075-4e0e553aa1ae.png", "cover_url": "", "cover_vertical_url": "", "social_image_url": "https://static.platzi.com/media/courses/OG-Como-prepararte-profesionalmente-para-el-futuro.png", "social_description": "Construye un perfil que te ayude a destacar en el mundo laboral, fortalece tus habilidades y prep\u00e1rate para enfrentar el futuro.", "lang": "es", "video": null, "url": "/clases/futuro-profesional/", "live_url": "/clases/futuro-profesional//live", "is_required": false}, {"id": 1008, "title": "C\u00f3mo ser un Product Designer por Aerolab", "slug": "product-designer", "free": false, "order": 0, "description": "Platzi y Aerolab te ense\u00f1an a crear productos que la gente ame. Conoce los elementos necesarios que llevar\u00e1n tu proyecto desde el concepto a la ejecuci\u00f3n, todo centrado en la mejor experiencia de usuario. ", "image": "https://static.platzi.com/media/courses/carrera-marketing-cover.jpg", "color": "#7DCD40", "badge": "https://static.platzi.com/media/achievements/product-design2x.png", "cover_url": "https://static.platzi.com/media/courses/cover_aerolab.jpg", "cover_vertical_url": "", "social_image_url": "https://static.platzi.com/media/courses/og-aerolab.png", "social_description": "Platzi y Aerolab te ense\u00f1an a crear productos que la gente ame. Conoce los elementos necesarios que llevar\u00e1n tu proyecto desde el concepto a la ejecuci\u00f3n, todo centrado en la mejor experiencia de usuario. ", "lang": "es", "video": "_c7Zu_GFbog", "url": "/clases/product-designer/", "live_url": "/clases/product-designer//live", "is_required": false}, {"id": 24, "title": "Comunidad Platzi", "slug": "comunidad-platzi" ...
#     window.endDate = new Date('2018-04-01T23:56:00-05:00');
#     window.currency = {
#       flag: 'https://static.platzi.com/media/flags/CO.png',
#       price: '$799.000',
#       fullPrice: '$890.000',
#     }
#     window.conf = {
#       confEnd: new Date('2018-05-06T09:00:00-05:00'),
#       isConfActive:  false ,
#     };
#     window.preConfDate = new Date('2018-05-05T09:00:00-05:00')
#     window.endBarDate = new Date('2018-09-27T16:00:00-04:56');
#     window.barState = '';
#     window.limitDate = new Date('');
#     window.limitedPromo = {
#       name: '',
#       token: '',
#     };
#   </script><script type="text/javascript" src="https://static.platzi.com/static/js/dll/modules.d86811abb99cf3b15864.js.gz"></script><script type="text/javascript" src="https://static.platzi.com/static/js/core/home-v3.2ce3ec38ec20b6bc7672.js.gz"></script><script type="text/javascript" src="https://static.platzi.com/static/js/d/contact-modal.b4340e3d744a50de60df.js.gz"></script><script type="text/javascript" src="https://static.platzi.com/static/js/core/header-v2.2ce3ec38ec20b6bc7672.js.gz"></script><script type="text/javascript" src="https://static.platzi.com/static/js/d/contact-modal.b4340e3d744a50de60df.js.gz"></script><!-- Google Rich Card --><script type="application/ld+json">
#             {
#                 "@context": "http://schema.org",
#                 "@type": "Organization",
#                 "name": "Platzi",
#                 "url": "https://platzi.com/",
#                 "description": "Aprende de expertos en programación, diseño, marketing, startups, video y web. Suscríbete hoy.",
#                 "foundingDate": "2013-01-01",
#                 "founders": [
#                     {
#                         "@type": "Person",
#                         "name": "John Freddy Vega"
#                     },
#                     {
#                         "@type": "Person",
#                         "name": "Christian Van Der Henst"
#                     }
#                 ],
#                 "sameAs": [
#                     "https://www.facebook.com/platzi/",
#                     "https://twitter.com/Platzi",
#                     "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ",
#                     "https://www.linkedin.com/school/2822346"
#                 ]
#             }
#         </script><!-- Start of LiveChat (www.livechatinc.com) code --><script type="text/javascript">
#             var $zoho=$zoho || {};$zoho.salesiq = $zoho.salesiq ||
#             {widgetcode:"852b603af4c84150cd4f53125b1c530734b9a85b166a9b1ecc95218a4de89824", values:{},ready:function(){}};
#             var d=document;s=d.createElement("script");s.type="text/javascript";s.id="zsiqscript";s.defer=true;
#             s.src="https://salesiq.zoho.com/widget";t=d.getElementsByTagName("script")[0];t.parentNode.insertBefore(s,t);d.write("<div id='zsiqwidget'></div>");
#             </script><!-- End of LiveChat code --></body></html>

# %% [markdown]
# ## Extracción de información del HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

courses_links = soup.select('.Card-link')
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /fundamentos-programacion/
# /desarrollo-php/
# /desarrollo-java/
# /arquitecto/
# /apple-fullstack/
# /desarrollo-android/
# /javascript/
# /multiplataforma/
# /negocios/
# /base-de-datos/
# /backend-ruby/
# /outbound-marketing/
# /servidores/
# /videojuegos/
# /email-marketing/
# /asp-net/
# /datos/
# /inbound-marketing/
# /backend-python/
# /ai/
# /producto/
# /backend-go/
# /desarrollo-wordpress/
# /audiovisual/
# /startups/
# /desarrollo-react/
# /data-marketing/
# /iot/
# /matematicas-programacion/
# /google-cloud/
# /ibm-cloud/
# /diseno-grafico/
# /desarrollo-unity/
# /habilidades-blandas/
# /blockchain-criptomonedas/
# /carrera-firebase/
# /seguridad-informatica/
# /desarrollo-angular/
# /ventas-mercadeo/
# /idioma-ingles/
# /gestion-proyectos/
# /estrategia-marketing/
# /transformacion/

# %% [markdown]
# ## Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23]})

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                           [34, 32, 32],
                           [23, 39, 23]], columns=[1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# ## Read data

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('web_scrapper_curso_data_eng/eluniversal_2018_10_06_articles.csv')

el_universal
# Out:
#                                                   body  \
# 0    \nLa austeridad se aplicó en el Sindicato de T...
# 1    \nEl inglés Lewis Hamilton (Mercedes), líder d...
# 2    [email protected]\nAquí, las tradiciones se pr...
# 3    A ella le advirtieron que matarían a su herman...
# 4    En el último año los salarios estadounidenses ...
# ..                                                 ...
# 144  El Poder Ejecutivo podría vetar la propuesta d...
# 145  \n[email protected]\nLa Secretaría de Segurida...
# 146  Cynthia Rodíguez se dio a conocer en La Academ...
# 147   Toggle navigation  SuscripcionesEl Universal ...
# 148  La socialité Kim Kardashian demostró que sus c...
#
#                                                  title  \
# 0    Austeridad “pega” a fiesta de sindicalizados d...
# 1                Hamilton con otra pole para su legado
# 2    Velas, tradición que alumbra a nuevas generaci...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 144               Ejecutivo vetaría aumento al Qrobús
# 145   Redoblan seguridad en primer cuadro de la Ciudad
# 146  Cynthia Rodríguez, ¿sigue o no con Carlos Rivera?
# 147                                                NaN
# 148                                                NaN
#
#                                                    url
# 0    http://www.eluniversal.com.mx/nacion/politica/...
# 1    http://www.eluniversal.com.mx/universal-deport...
# 2    http://oaxaca.eluniversal.com.mx/especiales/04...
# 3    http://www.elgrafico.mx/la-roja/hermana-no-le-...
# 4    http://www.viveusa.mx/negocios/los-trabajos-me...
# ..                                                 ...
# 144  http://www.eluniversalqueretaro.mx/portada/06-...
# 145  http://www.eluniversal.com.mx/metropoli/redobl...
# 146  http://www.unionguanajuato.mx/articulo/2018/10...
# 147  http://www.clubeluniversal.mx/content/suscripc...
# 148  http://www.viveusa.mx/showbiz/kim-kardashian-p...
#
# [149 rows x 3 columns]

# %% [markdown]
# ## Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0      Austeridad “pega” a fiesta de sindicalizados d...
# 1                  Hamilton con otra pole para su legado
# 2      Velas, tradición que alumbra a nuevas generaci...
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 144                 Ejecutivo vetaría aumento al Qrobús
# 145     Redoblan seguridad en primer cuadro de la Ciudad
# 146    Cynthia Rodríguez, ¿sigue o no con Carlos Rivera?
# 147                                                  NaN
# 148                                                  NaN
# Name: title, Length: 149, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0    Austeridad “pega” a fiesta de sindicalizados d...
# 1                Hamilton con otra pole para su legado
# 2    Velas, tradición que alumbra a nuevas generaci...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 144               Ejecutivo vetaría aumento al Qrobús
# 145   Redoblan seguridad en primer cuadro de la Ciudad
# 146  Cynthia Rodríguez, ¿sigue o no con Carlos Rivera?
# 147                                                NaN
# 148                                                NaN
#
#                                                    url
# 0    http://www.eluniversal.com.mx/nacion/politica/...
# 1    http://www.eluniversal.com.mx/universal-deport...
# 2    http://oaxaca.eluniversal.com.mx/especiales/04...
# 3    http://www.elgrafico.mx/la-roja/hermana-no-le-...
# 4    http://www.viveusa.mx/negocios/los-trabajos-me...
# ..                                                 ...
# 144  http://www.eluniversalqueretaro.mx/portada/06-...
# 145  http://www.eluniversal.com.mx/metropoli/redobl...
# 146  http://www.unionguanajuato.mx/articulo/2018/10...
# 147  http://www.clubeluniversal.mx/content/suscripc...
# 148  http://www.viveusa.mx/showbiz/kim-kardashian-p...
#
# [149 rows x 2 columns]

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nHay voces que señalan que la tercera guerra ...
# 11  \nTexto. Isis M. García \n“¿Cómo vas a ir a un...
# 12  \nEl Wolverhampton que entrena el portugués Nu...
# 13  \nExisten dos tipos de radiador en el auto: un...
# 14  \n1. ARTE Y DISEÑOBésame Mucho es un bazar par...
#
#                                                 title  \
# 10  Conflicto China-EU: riesgos más allá de lo com...
# 11                De desempleadas a ganar en dólares
# 12  Otro triunfo de los Wolves, con asistencia de ...
# 13  Tu carro tiene dos tipos de radiadores y esto ...
# 14  4 lugares imperdibles del Pueblo Mágico de Tod...
#
#                                                   url
# 10  http://www.eluniversal.com.mx/articulo/maurici...
# 11  http://www.eluniversal.com.mx/orgullomexicano/...
# 12  http://www.eluniversal.com.mx/universal-deport...
# 13  http://www.eluniversal.com.mx/autopistas/tu-ca...
# 14  http://www.eluniversal.com.mx/destinos/4-lugar...

# %%
el_universal.iloc[66]['title']
# Out:
# 'Javier Duarte y Karime recurren a treta legal'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nLa austeridad se aplicó en el Sindicato de T...
# 1    \nEl inglés Lewis Hamilton (Mercedes), líder d...
# 2    [email protected]\nAquí, las tradiciones se pr...
# 3    A ella le advirtieron que matarían a su herman...
# 4    En el último año los salarios estadounidenses ...
# Name: body, dtype: object

# %%
el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \nLa austeridad se aplicó en el Sindicato de T...
# 1    \nEl inglés Lewis Hamilton (Mercedes), líder d...
# 2    [email protected]\nAquí, las tradiciones se pr...
# 3    A ella le advirtieron que matarían a su herman...
# 4    En el último año los salarios estadounidenses ...
# ..                                                 ...
# 144  El Poder Ejecutivo podría vetar la propuesta d...
# 145  \n[email protected]\nLa Secretaría de Segurida...
# 146  Cynthia Rodíguez se dio a conocer en La Academ...
# 147   Toggle navigation  SuscripcionesEl Universal ...
# 148  La socialité Kim Kardashian demostró que sus c...
#
#                                                  title
# 0    Austeridad “pega” a fiesta de sindicalizados d...
# 1                Hamilton con otra pole para su legado
# 2    Velas, tradición que alumbra a nuevas generaci...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 144               Ejecutivo vetaría aumento al Qrobús
# 145   Redoblan seguridad en primer cuadro de la Ciudad
# 146  Cynthia Rodríguez, ¿sigue o no con Carlos Rivera?
# 147                                                NaN
# 148                                                NaN
#
# [149 rows x 2 columns]

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# ## Missing data

# %% [markdown]
# ## Duplicate values

# %% [markdown]
# ## Final table

# %% [markdown]
# ## Combining datasets

# %% [markdown]
# ## Descriptive analysis
